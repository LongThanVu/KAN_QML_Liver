# %%
# ============================================================
# 0. IMPORTS
# ============================================================
from kan import KAN
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pennylane as qml
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, RobustScaler,MinMaxScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, balanced_accuracy_score, average_precision_score,
    matthews_corrcoef, cohen_kappa_score, brier_score_loss, roc_auc_score
)
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import KFold
import random
import copy
# ============================================================
# 1. SEEDING (REPRODUCIBILITY)
# ============================================================

seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# ============================================================
# 2. DATA LOADING & PREPROCESSING
# ============================================================

df = pd.read_csv("IndianLiverPatientDataset(ILPD).csv")
df = df.copy()

# Encode categorical
df["Gender"] = df["Gender"].map({"Male": 0, "Female": 1})

# Remap label: {1,2} -> {1,0}
df["Sickness"] = df["Sickness"].replace(2, 0)

# Handle NaN
df["A/G"] = df["A/G"].fillna(df["A/G"].mean())

# Separate positive / negative
pos = df[df["Sickness"] == 1]
neg = df[df["Sickness"] == 0]

# Balanced test set
n_test = min(len(pos), len(neg)) // 2
test = pd.concat([
    pos.sample(n=n_test, random_state=seed),
    neg.sample(n=n_test, random_state=seed)
]).reset_index(drop=True)

# Drop specific indices (logic from original code)
drop_idx = [3, 31, 35, 89, 104, 106, 114, 115, 116, 124, 130, 132, 135, 139, 143, 150, 151, 157, 161]
test = test.drop([i for i in drop_idx if i in test.index], errors="ignore")

train = df.drop(test.index).reset_index(drop=True)
test = test.drop_duplicates().reset_index(drop=True)
train = train.drop_duplicates().reset_index(drop=True)

# Split X / y
X_train_df, y_train_df = train.drop(columns=["Sickness"]), train["Sickness"]
X_test_df, y_test_df = test.drop(columns=["Sickness"]), test["Sickness"]

# Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_df)
X_test = scaler.transform(X_test_df)

# Torch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)

# X_train = torch.clamp(X_train, -3, 3)
# X_test  = torch.clamp(X_test,  -3, 3)
# 🔥 RẤT QUAN TRỌNG: ổn định spline cho KAN
# X_train = torch.tanh(X_train)
# X_test  = torch.tanh(X_test)

X_train = X_train*(np.pi/2)
X_test  = X_test*(np.pi/2)

# Labels
y_train = torch.tensor(y_train_df.values, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test_df.values, dtype=torch.float32).unsqueeze(1)

# %%
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.array([0, 1]),
    y=y_train_df.values
)

class_weight_dict = {0: class_weights[0], 1: class_weights[1]}

# Smooth class weights (giống Keras)
smooth_factor = 0.7
mean_weight = np.mean(list(class_weight_dict.values()))

for k in class_weight_dict:
    class_weight_dict[k] = (
        smooth_factor * class_weight_dict[k]
        + (1 - smooth_factor) * mean_weight
    )

class_weight_tensor = {
    0: torch.tensor(class_weight_dict[0], dtype=torch.float32),
    1: torch.tensor(class_weight_dict[1], dtype=torch.float32)
}

print("Smoothed class weights:", class_weight_dict)
# Out:
# Smoothed class weights: {0: np.float64(1.53656627271572), 1: np.float64(0.8570796797560047)}

# %%
# ============================================================
# 3. QUANTUM LAYER
# ============================================================

n_qubits = 2
n_layers = 1

dev = qml.device("default.qubit", wires=n_qubits, seed=seed)

@qml.qnode(dev, interface="torch")
def qnode(inputs, weights):
    qml.AngleEmbedding(inputs, wires=range(n_qubits))
    qml.BasicEntanglerLayers(weights, wires=range(n_qubits))
    return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

weight_shapes = {"weights": (n_layers, n_qubits)}

# %%
# @qml.qnode(dev, interface="torch")
# def qnode(inputs, weights):
#     for l in range(n_layers):
#         qml.AngleEmbedding(inputs, wires=range(n_qubits))
#         for i in range(n_qubits):
#             qml.RY(weights[l, i], wires=i)
#         for i in range(n_qubits - 1):
#             qml.CNOT(wires=[i, i + 1])
#     return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]
# weight_shapes = {"weights": (n_layers, n_qubits)}

# %%
# ============================================================
# 4. BINARY FOCAL LOSS (SOFT CLASS WEIGHTING)
# ============================================================

# class BinaryFocalLoss(nn.Module):
#     def __init__(self, gamma=1.0, alpha=0.3, class_weight=None):
#         super().__init__()
#         self.gamma = gamma
#         self.alpha = alpha
#         self.class_weight = class_weight

#     def forward(self, probs, targets):
#         bce = nn.functional.binary_cross_entropy(
#             probs, targets, reduction="none"
#         )
#         pt = torch.exp(-bce)

#         alpha_t = self.alpha * targets + (1 - self.alpha) * (1 - targets)
#         focal = alpha_t * (1 - pt) ** self.gamma * bce

#         # Class weight giống Keras fit(class_weight=...)
#         if self.class_weight is not None:
#             weight = (
#                 self.class_weight[1] * targets
#                 + self.class_weight[0] * (1 - targets)
#             )
#             focal = focal * weight

#         return focal.mean()
import torch
import torch.nn as nn

class BinaryFocalLoss(nn.Module):
    def __init__(self, alpha=0.3, gamma=1.0, reduction="mean", eps=1e-7):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        self.eps = eps

    def forward(self, y_pred, y_true):
        y_true = y_true.float()
        y_pred = torch.clamp(y_pred, self.eps, 1.0 - self.eps)

        pos_loss = - self.alpha * (1 - y_pred) ** self.gamma * y_true * torch.log(y_pred)
        neg_loss = - (1 - self.alpha) * y_pred ** self.gamma * (1 - y_true) * torch.log(1 - y_pred)

        loss = pos_loss + neg_loss

        if self.reduction == "mean":
            return loss.mean()
        return loss.sum()

# %%
# ============================================================
# 5. MODEL ARCHITECTURE
# ============================================================

class HybridKANQuantumModel(nn.Module):
    def __init__(self, input_dim):
        super().__init__()

        # ======================
        # KAN NETWORK
        # ======================
        self.kan = KAN(
            width=[input_dim, 16, 8, n_qubits],  # bạn có thể chỉnh
            grid=5,       # số điểm spline
            k=3,          # spline bậc 3 (cubic)
            seed=seed
        )

        # ======================
        # QUANTUM LAYER
        # ======================
        self.q_layer = qml.qnn.TorchLayer(qnode, weight_shapes)

        # ======================
        # OUTPUT LAYER
        # ======================
        self.fc_out = nn.Linear(n_qubits, 1)

        nn.init.xavier_uniform_(self.fc_out.weight)
        nn.init.zeros_(self.fc_out.bias)

    def forward(self, x):
        x = self.kan(x)        # ⬅️ KAN thay MLP
        x = self.q_layer(x)   # ⬅️ Quantum layer
        x = self.fc_out(x)
        return torch.sigmoid(x)

# %%
# ============================================================
# 6. TRAIN / VALIDATION SPLIT & CLASS WEIGHTS (Sửa đổi để giống Keras)
# ============================================================

# 1. TÍNH CLASS WEIGHTS (Giống hệt logic Keras)
# Chuyển y_train về numpy để tính toán
y_train_np = y_train.numpy().flatten()
class_weights = compute_class_weight('balanced', classes=np.unique(y_train_np), y=y_train_np)

# Smoothing factor (alpha = 0.7 như code Keras)
alpha_smooth = 0.7
class_weight_dict = {i: 1 + alpha_smooth * (w - 1) for i, w in enumerate(class_weights)}
print("Class Weights Dict:", class_weight_dict)

# 2. CHIA VALIDATION (Cắt đuôi 25% giống Keras validation_split=0.25)
# Lưu ý: Keras cắt 25% cuối cùng làm val TRƯỚC KHI shuffle
dataset_size = len(X_train)
val_size = int(0.25 * dataset_size)
train_size = dataset_size - val_size

# Slicing thủ công thay vì dùng random_split
X_train_split = X_train[:train_size]
y_train_split = y_train[:train_size]
X_val_split   = X_train[train_size:]
y_val_split   = y_train[train_size:]

# Tạo DataLoader
train_loader = DataLoader(TensorDataset(X_train_split, y_train_split), batch_size=32, shuffle=True)
val_loader   = DataLoader(TensorDataset(X_val_split, y_val_split), batch_size=32, shuffle=False)
test_loader  = DataLoader(TensorDataset(X_test, y_test), batch_size=32, shuffle=False)
# Out:
# Class Weights Dict: {0: np.float64(1.4775193798449613), 1: np.float64(0.7980327868852459)}

# %%
# ============================================================
# 7. TRAINING SETUP
# ============================================================

model = HybridKANQuantumModel(X_train.shape[1])

optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = BinaryFocalLoss(alpha=0.3, gamma=1.0)

# Early stopping
patience = 500
best_loss = np.inf
counter = 0
best_state = None
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
# ============================================================
# 8. TRAINING LOOP
# ============================================================

epochs = 200
for epoch in range(epochs):
    # --- TRAINING PHASE ---
    model.train()
    train_loss = 0

    for x, y in train_loader:
        optimizer.zero_grad()
        out = model(x)
        
        # 1. Tính raw loss (dạng vector, vì reduction='none' trong criterion)
        raw_loss = criterion(out, y) 
        
        # 2. Lấy trọng số cho từng mẫu trong batch từ class_weight_dict
        batch_weights = torch.tensor([class_weight_dict[int(yi.item())] for yi in y], dtype=torch.float32)
        
        # 3. Nhân trọng số và tính trung bình để ra một số thực (Scalar)
        # unsqueeze(1) giúp batch_weights có kích thước [32, 1] khớp với raw_loss
        loss = (raw_loss * batch_weights.unsqueeze(1)).mean()
        
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * x.size(0)

    train_loss /= len(train_loader.dataset)

    # --- VALIDATION PHASE (ĐÃ SỬA LỖI) ---
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for x, y in val_loader:
            out = model(x)
            
            # Tính raw loss (vector)
            raw_loss = criterion(out, y)
            
            # Lấy trọng số tương tự như training để tính loss công bằng
            batch_weights = torch.tensor([class_weight_dict[int(yi.item())] for yi in y], dtype=torch.float32)
            
            # Nhân trọng số và tính trung bình (Scalar)
            loss = (raw_loss * batch_weights.unsqueeze(1)).mean()
            
            # Cộng dồn loss (lúc này loss.item() hoạt động bình thường vì loss là scalar)
            val_loss += loss.item() * x.size(0)

    val_loss /= len(val_loader.dataset)
    print(f"Epoch {epoch+1}: train_loss={train_loss:.4f}, val_loss={val_loss:.4f}")

    # --- EARLY STOPPING ---
    if val_loss < best_loss:
        best_loss = val_loss
        best_state = model.state_dict()
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping")
            break

# Load lại trọng số tốt nhất sau khi training xong
model.load_state_dict(best_state)
# Out:
# Epoch 1: train_loss=0.1789, val_loss=0.1290
# Epoch 2: train_loss=0.1699, val_loss=0.1236
# Epoch 3: train_loss=0.1602, val_loss=0.1193
# Epoch 4: train_loss=0.1546, val_loss=0.1160
# Epoch 5: train_loss=0.1483, val_loss=0.1136
# Epoch 6: train_loss=0.1449, val_loss=0.1112
# Epoch 7: train_loss=0.1427, val_loss=0.1093
# Epoch 8: train_loss=0.1395, val_loss=0.1078
# Epoch 9: train_loss=0.1387, val_loss=0.1061
# Epoch 10: train_loss=0.1366, val_loss=0.1050
# Epoch 11: train_loss=0.1356, val_loss=0.1039
# Epoch 12: train_loss=0.1351, val_loss=0.1029
# Epoch 13: train_loss=0.1330, val_loss=0.1017
# Epoch 14: train_loss=0.1321, val_loss=0.1005
# Epoch 15: train_loss=0.1321, val_loss=0.0999
# Epoch 16: train_loss=0.1302, val_loss=0.0990
# Epoch 17: train_loss=0.1294, val_loss=0.0984
# Epoch 18: train_loss=0.1289, val_loss=0.0977
# Epoch 19: train_loss=0.1277, val_loss=0.0974
# Epoch 20: train_loss=0.1279, val_loss=0.0968
# Epoch 21: train_loss=0.1272, val_loss=0.0964
# Epoch 22: train_loss=0.1263, val_loss=0.0958
# Epoch 23: train_loss=0.1256, val_loss=0.0952
# Epoch 24: train_loss=0.1247, val_loss=0.0945
# Epoch 25: train_loss=0.1243, val_loss=0.0941
# Epoch 26: train_loss=0.1239, val_loss=0.0937
# Epoch 27: train_loss=0.1228, val_loss=0.0938
# Epoch 28: train_loss=0.1217, val_loss=0.0944
# Epoch 29: train_loss=0.1224, val_loss=0.0939
# Epoch 30: train_loss=0.1198, val_loss=0.0930
# Epoch 31: train_loss=0.1190, val_loss=0.0934
# Epoch 32: train_loss=0.1182, val_loss=0.0929
# Epoch 33: train_loss=0.1163, val_loss=0.0929
# Epoch 34: train_loss=0.1145, val_loss=0.0918
# Epoch 35: train_loss=0.1149, val_loss=0.0905
# Epoch 36: train_loss=0.1127, val_loss=0.0931
# Epoch 37: train_loss=0.1104, val_loss=0.0937
# Epoch 38: train_loss=0.1077, val_loss=0.0914
# Epoch 39: train_loss=0.1061, val_loss=0.0929
# Epoch 40: train_loss=0.1044, val_loss=0.0969
# Epoch 41: train_loss=0.1014, val_loss=0.0962
# Epoch 42: train_loss=0.0982, val_loss=0.1010
# Epoch 43: train_loss=0.0958, val_loss=0.0989
# Epoch 44: train_loss=0.0928, val_loss=0.1025
# Epoch 45: train_loss=0.0895, val_loss=0.0996
# Epoch 46: train_loss=0.0865, val_loss=0.1060
# Epoch 47: train_loss=0.0843, val_loss=0.1076
# Epoch 48: train_loss=0.0802, val_loss=0.1094
# Epoch 49: train_loss=0.0784, val_loss=0.1095
# Epoch 50: train_loss=0.0745, val_loss=0.1150
# Epoch 51: train_loss=0.0727, val_loss=0.1092
# Epoch 52: train_loss=0.0678, val_loss=0.1206
# Epoch 53: train_loss=0.0695, val_loss=0.1179
# Epoch 54: train_loss=0.0666, val_loss=0.1115
# Epoch 55: train_loss=0.0629, val_loss=0.1242
# Epoch 56: train_loss=0.0593, val_loss=0.1274
# Epoch 57: train_loss=0.0565, val_loss=0.1295
# Epoch 58: train_loss=0.0554, val_loss=0.1336
# Epoch 59: train_loss=0.0529, val_loss=0.1365
# Epoch 60: train_loss=0.0504, val_loss=0.1352
# Epoch 61: train_loss=0.0494, val_loss=0.1415
# Epoch 62: train_loss=0.0462, val_loss=0.1412
# Epoch 63: train_loss=0.0475, val_loss=0.1463
# Epoch 64: train_loss=0.0436, val_loss=0.1515
# Epoch 65: train_loss=0.0426, val_loss=0.1468
# Epoch 66: train_loss=0.0398, val_loss=0.1529
# Epoch 67: train_loss=0.0391, val_loss=0.1495
# Epoch 68: train_loss=0.0371, val_loss=0.1541
# Epoch 69: train_loss=0.0346, val_loss=0.1617
# Epoch 70: train_loss=0.0332, val_loss=0.1603
# Epoch 71: train_loss=0.0318, val_loss=0.1663
# Epoch 72: train_loss=0.0316, val_loss=0.1635
# Epoch 73: train_loss=0.0298, val_loss=0.1654
# Epoch 74: train_loss=0.0287, val_loss=0.1708
# Epoch 75: train_loss=0.0259, val_loss=0.1741
# Epoch 76: train_loss=0.0256, val_loss=0.1818
# Epoch 77: train_loss=0.0256, val_loss=0.1731
# Epoch 78: train_loss=0.0237, val_loss=0.1792
# Epoch 79: train_loss=0.0233, val_loss=0.1817
# Epoch 80: train_loss=0.0219, val_loss=0.1874
# Epoch 81: train_loss=0.0202, val_loss=0.1914
# Epoch 82: train_loss=0.0200, val_loss=0.1877
# Epoch 83: train_loss=0.0192, val_loss=0.1911
# Epoch 84: train_loss=0.0194, val_loss=0.1947
# Epoch 85: train_loss=0.0169, val_loss=0.1962
# Epoch 86: train_loss=0.0171, val_loss=0.1922
# Epoch 87: train_loss=0.0160, val_loss=0.2045
# Epoch 88: train_loss=0.0158, val_loss=0.2006
# Epoch 89: train_loss=0.0143, val_loss=0.2001
# Epoch 90: train_loss=0.0137, val_loss=0.2018
# Epoch 91: train_loss=0.0138, val_loss=0.1986
# Epoch 92: train_loss=0.0136, val_loss=0.2127
# Epoch 93: train_loss=0.0124, val_loss=0.2052
# Epoch 94: train_loss=0.0118, val_loss=0.2123
# Epoch 95: train_loss=0.0111, val_loss=0.2180
# Epoch 96: train_loss=0.0108, val_loss=0.2171
# Epoch 97: train_loss=0.0108, val_loss=0.2211
# Epoch 98: train_loss=0.0108, val_loss=0.2308
# Epoch 99: train_loss=0.0099, val_loss=0.2275
# Epoch 100: train_loss=0.0092, val_loss=0.2321
# Epoch 101: train_loss=0.0088, val_loss=0.2327
# Epoch 102: train_loss=0.0084, val_loss=0.2338
# Epoch 103: train_loss=0.0078, val_loss=0.2374
# Epoch 104: train_loss=0.0076, val_loss=0.2397
# Epoch 105: train_loss=0.0074, val_loss=0.2447
# Epoch 106: train_loss=0.0070, val_loss=0.2421
# Epoch 107: train_loss=0.0063, val_loss=0.2475
# Epoch 108: train_loss=0.0061, val_loss=0.2506
# Epoch 109: train_loss=0.0059, val_loss=0.2516
# Epoch 110: train_loss=0.0057, val_loss=0.2530
# Epoch 111: train_loss=0.0054, val_loss=0.2551
# Epoch 112: train_loss=0.0051, val_loss=0.2566
# Epoch 113: train_loss=0.0050, val_loss=0.2570
# Epoch 114: train_loss=0.0048, val_loss=0.2590
# Epoch 115: train_loss=0.0045, val_loss=0.2612
# Epoch 116: train_loss=0.0045, val_loss=0.2616
# Epoch 117: train_loss=0.0042, val_loss=0.2629
# Epoch 118: train_loss=0.0042, val_loss=0.2659
# Epoch 119: train_loss=0.0040, val_loss=0.2694
# Epoch 120: train_loss=0.0038, val_loss=0.2689
# Epoch 121: train_loss=0.0038, val_loss=0.2695
# Epoch 122: train_loss=0.0036, val_loss=0.2717
# Epoch 123: train_loss=0.0034, val_loss=0.2717
# Epoch 124: train_loss=0.0034, val_loss=0.2734
# Epoch 125: train_loss=0.0033, val_loss=0.2750
# Epoch 126: train_loss=0.0032, val_loss=0.2767
# Epoch 127: train_loss=0.0031, val_loss=0.2774
# Epoch 128: train_loss=0.0030, val_loss=0.2789
# Epoch 129: train_loss=0.0029, val_loss=0.2797
# Epoch 130: train_loss=0.0028, val_loss=0.2795
# Epoch 131: train_loss=0.0028, val_loss=0.2817
# Epoch 132: train_loss=0.0027, val_loss=0.2833
# Epoch 133: train_loss=0.0027, val_loss=0.2815
# Epoch 134: train_loss=0.0026, val_loss=0.2838
# Epoch 135: train_loss=0.0025, val_loss=0.2859
# Epoch 136: train_loss=0.0025, val_loss=0.2874
# Epoch 137: train_loss=0.0025, val_loss=0.2881
# Epoch 138: train_loss=0.0023, val_loss=0.2870
# Epoch 139: train_loss=0.0023, val_loss=0.2880
# Epoch 140: train_loss=0.0023, val_loss=0.2887
# Epoch 141: train_loss=0.0022, val_loss=0.2911
# Epoch 142: train_loss=0.0022, val_loss=0.2934
# Epoch 143: train_loss=0.0021, val_loss=0.2947
# Epoch 144: train_loss=0.0020, val_loss=0.2948
# Epoch 145: train_loss=0.0020, val_loss=0.2956
# Epoch 146: train_loss=0.0020, val_loss=0.2958
# Epoch 147: train_loss=0.0020, val_loss=0.2954
# Epoch 148: train_loss=0.0019, val_loss=0.2985
# Epoch 149: train_loss=0.0019, val_loss=0.2969
# Epoch 150: train_loss=0.0018, val_loss=0.2973
# Epoch 151: train_loss=0.0019, val_loss=0.3001
# Epoch 152: train_loss=0.0018, val_loss=0.3015
# Epoch 153: train_loss=0.0018, val_loss=0.3017
# Epoch 154: train_loss=0.0017, val_loss=0.3020
# Epoch 155: train_loss=0.0017, val_loss=0.3020
# Epoch 156: train_loss=0.0017, val_loss=0.3031
# Epoch 157: train_loss=0.0017, val_loss=0.3042
# Epoch 158: train_loss=0.0017, val_loss=0.3044
# Epoch 159: train_loss=0.0016, val_loss=0.3057
# Epoch 160: train_loss=0.0016, val_loss=0.3066
# Epoch 161: train_loss=0.0016, val_loss=0.3065
# Epoch 162: train_loss=0.0015, val_loss=0.3070
# Epoch 163: train_loss=0.0016, val_loss=0.3078
# Epoch 164: train_loss=0.0015, val_loss=0.3085
# Epoch 165: train_loss=0.0015, val_loss=0.3096
# Epoch 166: train_loss=0.0015, val_loss=0.3101
# Epoch 167: train_loss=0.0015, val_loss=0.3114
# Epoch 168: train_loss=0.0014, val_loss=0.3116
# Epoch 169: train_loss=0.0014, val_loss=0.3107
# Epoch 170: train_loss=0.0014, val_loss=0.3111
# Epoch 171: train_loss=0.0014, val_loss=0.3123
# Epoch 172: train_loss=0.0014, val_loss=0.3140
# Epoch 173: train_loss=0.0014, val_loss=0.3145
# Epoch 174: train_loss=0.0013, val_loss=0.3152
# Epoch 175: train_loss=0.0013, val_loss=0.3159
# Epoch 176: train_loss=0.0013, val_loss=0.3166
# Epoch 177: train_loss=0.0013, val_loss=0.3160
# Epoch 178: train_loss=0.0012, val_loss=0.3171
# Epoch 179: train_loss=0.0013, val_loss=0.3163
# Epoch 180: train_loss=0.0013, val_loss=0.3176
# Epoch 181: train_loss=0.0013, val_loss=0.3191
# Epoch 182: train_loss=0.0012, val_loss=0.3196
# Epoch 183: train_loss=0.0012, val_loss=0.3184
# Epoch 184: train_loss=0.0012, val_loss=0.3197
# Epoch 185: train_loss=0.0012, val_loss=0.3214
# Epoch 186: train_loss=0.0012, val_loss=0.3233
# Epoch 187: train_loss=0.0012, val_loss=0.3243
# Epoch 188: train_loss=0.0012, val_loss=0.3249
# Epoch 189: train_loss=0.0011, val_loss=0.3258
# Epoch 190: train_loss=0.0011, val_loss=0.3257
# Epoch 191: train_loss=0.0011, val_loss=0.3269
# Epoch 192: train_loss=0.0011, val_loss=0.3281
# Epoch 193: train_loss=0.0011, val_loss=0.3281
# Epoch 194: train_loss=0.0011, val_loss=0.3278
# Epoch 195: train_loss=0.0011, val_loss=0.3280
# Epoch 196: train_loss=0.0011, val_loss=0.3285
# Epoch 197: train_loss=0.0011, val_loss=0.3289
# Epoch 198: train_loss=0.0011, val_loss=0.3297
# Epoch 199: train_loss=0.0011, val_loss=0.3300
# Epoch 200: train_loss=0.0010, val_loss=0.3318
# <All keys matched successfully>

# %%
# ============================================================
# 9. EVALUATION
# ============================================================

model.eval()
y_probs, y_true = [], []

with torch.no_grad():
    for x, y in test_loader:
        out = model(x)
        y_probs.extend(out.numpy())
        y_true.extend(y.numpy())

y_probs = np.array(y_probs)
y_true = np.array(y_true)
y_pred = (y_probs >= 0.5).astype(int)

tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

print("\n=== METRICS ===")
print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
print(f"Precision: {precision_score(y_true, y_pred):.4f}")
print(f"Recall: {recall_score(y_true, y_pred):.4f}")
print(f"Specificity: {tn / (tn + fp):.4f}")
print(f"F1-score: {f1_score(y_true, y_pred):.4f}")
print(f"Balanced Accuracy: {balanced_accuracy_score(y_true, y_pred):.4f}")
print(f"ROC AUC: {roc_auc_score(y_true, y_probs):.4f}")
print(f"PR AUC: {average_precision_score(y_true, y_probs):.4f}")
print(f"MCC: {matthews_corrcoef(y_true, y_pred):.4f}")
print(f"Cohen Kappa: {cohen_kappa_score(y_true, y_pred):.4f}")
print(f"Brier Score: {brier_score_loss(y_true, y_probs):.4f}")
# Out:
# === METRICS ===
# Accuracy: 0.8904
# Precision: 0.8556
# Recall: 0.9625
# Specificity: 0.8030
# F1-score: 0.9059
# Balanced Accuracy: 0.8828
# ROC AUC: 0.9256
# PR AUC: 0.8928
# MCC: 0.7835
# Cohen Kappa: 0.7758
# Brier Score: 0.0929

# %%
# # ======================
# # KAN VISUALIZATION
# # ======================
# model.kan.plot()

# %%
# def plot_learned_function(model, X, feature_idx, n_points=200):
#     model.eval()

#     x_min = X[:, feature_idx].min()
#     x_max = X[:, feature_idx].max()
#     x_vals = torch.linspace(x_min, x_max, n_points)

#     X_base = X.mean(dim=0).repeat(n_points, 1)
#     X_base[:, feature_idx] = x_vals

#     with torch.no_grad():
#         y_vals = model(X_base).squeeze()

#     return x_vals.cpu().numpy(), y_vals.cpu().numpy()

# %%
# x, y = plot_learned_function(model, X_train, feature_idx=2)

# plt.plot(x, y)
# plt.xlabel("Feature 2 (scaled)")
# plt.ylabel("Model output")
# plt.title("Learned function for feature 2")
# plt.show()

# %% [markdown]
# ### Importance sensitivity

# %%
# def kan_feature_importance_sensitivity(model, X, eps=1e-2):
#     model.eval()
#     base_output = model(X).detach()

#     input_dim = X.shape[1]
#     importance = torch.zeros(input_dim)

#     for i in range(input_dim):
#         X_perturbed = X.clone()
#         X_perturbed[:, i] += eps

#         pert_output = model(X_perturbed).detach()
#         importance[i] = torch.mean(torch.abs(pert_output - base_output))

#     importance = importance / importance.sum()
#     return importance
# importance = kan_feature_importance_sensitivity(
#     model,
#     X_train
# )

# for name, score in zip(X_train_df.columns, importance):
#     print(f"{name}: {score:.3f}")

# %%
# # ============================
# # SIMPLIFY KAN (PRUNING)
# # ============================
# pruned_model = HybridKANQuantumModel(X_train.shape[1])
# pruned_model.load_state_dict(best_state)
# pruned_model.eval()

# with torch.no_grad():
#     _ = pruned_model(X_train)
# pruned_model.kan.prune()
# pruned_model.kan.plot()

# plt.savefig(
#     "kan_structure.png",
#     dpi=1000,                 # chuẩn thesis / paper
#     bbox_inches="tight"
# )
# plt.close()

# %%
# x, y = plot_learned_function(model, X_train, feature_idx=2)

# plt.plot(x, y)
# plt.xlabel("Feature 2 (scaled)")
# plt.ylabel("Model output")
# plt.title("Learned function for feature 2")
# plt.show()
