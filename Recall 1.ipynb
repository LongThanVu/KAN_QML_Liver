# %%
# ============================================================
# 0. IMPORTS
# ============================================================
from kan import KAN
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pennylane as qml
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, RobustScaler,MinMaxScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, balanced_accuracy_score, average_precision_score,
    matthews_corrcoef, cohen_kappa_score, brier_score_loss, roc_auc_score
)
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import KFold
import random
import copy
# ============================================================
# 1. SEEDING (REPRODUCIBILITY)
# ============================================================
batch_size = 32
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# ============================================================
# 2. DATA LOADING & PREPROCESSING
# ============================================================

df = pd.read_csv("IndianLiverPatientDataset(ILPD).csv")
df = df.copy()

# Encode categorical
df["Gender"] = df["Gender"].map({"Male": 0, "Female": 1})

# Remap label: {1,2} -> {1,0}
df["Sickness"] = df["Sickness"].replace(2, 0)

# Handle NaN
# df["A/G"] = df["A/G"].fillna(df["A/G"].mean())

# Separate positive / negative
pos = df[df["Sickness"] == 1]
neg = df[df["Sickness"] == 0]

# Balanced test set
n_test = min(len(pos), len(neg)) // 2
test = pd.concat([
    pos.sample(n=n_test, random_state=seed),
    neg.sample(n=n_test, random_state=seed)
]).reset_index(drop=True)

# Drop specific indices (logic from original code)
drop_idx = [3, 31, 35, 89, 104, 106, 114, 115, 116, 124, 130, 132, 135, 139, 143, 150, 151, 157, 161]
test = test.drop([i for i in drop_idx if i in test.index], errors="ignore")

train = df.drop(test.index).reset_index(drop=True)
test = test.drop_duplicates().reset_index(drop=True)
train = train.drop_duplicates().reset_index(drop=True)

# Handle NaN
ag_mean = train["A/G"].mean()
train["A/G"] = train["A/G"].fillna(ag_mean)
test["A/G"]  = test["A/G"].fillna(ag_mean)

# Split X / y
X_train_df, y_train_df = train.drop(columns=["Sickness"]), train["Sickness"]
X_test_df, y_test_df = test.drop(columns=["Sickness"]), test["Sickness"]



# Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_df)
X_test = scaler.transform(X_test_df)

# Torch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)

X_train = X_train*((np.pi/2))
X_test  = X_test*((np.pi/2))

# Labels
y_train = torch.tensor(y_train_df.values, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test_df.values, dtype=torch.float32).unsqueeze(1)


# CHIA VALIDATION (Cắt đuôi 25% giống Keras validation_split=0.25)
# Lưu ý: Keras cắt 25% cuối cùng làm val TRƯỚC KHI shuffle
dataset_size = len(X_train)
val_size = int(0.25 * dataset_size)
train_size = dataset_size - val_size

# Slicing thủ công thay vì dùng random_split
X_train_split = X_train[:train_size]
y_train_split = y_train[:train_size]
X_val_split   = X_train[train_size:]
y_val_split   = y_train[train_size:]

# Tạo DataLoader
train_loader = DataLoader(TensorDataset(X_train_split, y_train_split), batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(TensorDataset(X_val_split, y_val_split), batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(TensorDataset(X_test, y_test), batch_size=batch_size, shuffle=False)

# from sklearn.preprocessing import QuantileTransformer

# qt = QuantileTransformer(
#     n_quantiles=100,
#     output_distribution="normal",
#     random_state=42
# )
# X_train = qt.fit_transform(X_train_df)
# X_test = qt.fit_transform(X_test_df)
# X_train = torch.tanh(torch.tensor(X_train, dtype=torch.float32))
# X_test = torch.tanh(torch.tensor(X_test, dtype=torch.float32))
# X_train = torch.clamp(X_train, -3, 3)
# X_test  = torch.clamp(X_test,  -3, 3)
# 🔥 RẤT QUAN TRỌNG: ổn định spline cho KAN
# X_train = torch.tanh(X_train)
# X_test  = torch.tanh(X_test)

# %%
# # ============================================================
# # CLASS WEIGHT: EFFECTIVE NUMBER OF SAMPLES (CVPR 2019)
# # ============================================================

# def effective_num_weight(n_samples, beta=0.3):
#     return (1 - beta) / (1 - beta ** n_samples)

# # y_train đã là tensor → chuyển sang numpy
# y_train_np = y_train.numpy().flatten()

# n0 = (y_train_np == 0).sum()
# n1 = (y_train_np == 1).sum()

# w0 = effective_num_weight(n0, beta=0.3)
# w1 = effective_num_weight(n1, beta=0.3)

# # Normalize để mean = 1 (rất quan trọng)
# mean_w = (w0 + w1) / 2

# class_weight_dict = {
#     0: float(w0 / mean_w),
#     1: float(w1 / mean_w)
# }

# print("Effective class weights:", class_weight_dict)

# %%
# ============================================================
# 3. QUANTUM LAYER
# ============================================================

n_qubits = 2
n_layers = 1

dev = qml.device("default.qubit", wires=n_qubits, seed=seed)

@qml.qnode(dev, interface="torch")
def qnode(inputs, weights):
    qml.AngleEmbedding(inputs, wires=range(n_qubits))
    qml.BasicEntanglerLayers(weights, wires=range(n_qubits))
    return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

weight_shapes = {"weights": (n_layers, n_qubits)}

# %%
# @qml.qnode(dev, interface="torch")
# def qnode(inputs, weights):
#     for l in range(n_layers):
#         qml.AngleEmbedding(inputs, wires=range(n_qubits))
#         for i in range(n_qubits):
#             qml.RY(weights[l, i], wires=i)
#         for i in range(n_qubits - 1):
#             qml.CNOT(wires=[i, i + 1])
#     return [qml.expval(qml.PauliY(i)) for i in range(n_qubits)]
# weight_shapes = {"weights": (n_layers, n_qubits)}

# %%
import torch
import torch.nn as nn

class BinaryFocalLoss(nn.Module):
    def __init__(self, alpha=0.3, gamma=1.0, reduction="mean", eps=1e-7):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        self.eps = eps

    def forward(self, y_pred, y_true):
        y_true = y_true.float()
        y_pred = torch.clamp(y_pred, self.eps, 1.0 - self.eps)

        pos_loss = - self.alpha * (1 - y_pred) ** self.gamma * y_true * torch.log(y_pred)
        neg_loss = - (1 - self.alpha) * y_pred ** self.gamma * (1 - y_true) * torch.log(1 - y_pred)

        loss = pos_loss + neg_loss

        if self.reduction == "mean":
            return loss.mean()
        return loss.sum()

# %%
# ============================================================
# 5. MODEL ARCHITECTURE
# ============================================================

class HybridKANQuantumModel(nn.Module):
    def __init__(self, input_dim):
        super().__init__()

        # ======================
        # KAN NETWORK
        # ======================
        self.kan = KAN(
            width=[input_dim,7,5, n_qubits],  # bạn có thể chỉnh
            grid=5,       # số điểm spline
            k=3,          # spline bậc 3 (cubic)
            seed=seed
        )

        # ======================
        # QUANTUM LAYER
        # ======================
        self.q_layer = qml.qnn.TorchLayer(qnode, weight_shapes)

        # ======================
        # OUTPUT LAYER
        # ======================
        self.fc_out = nn.Linear(n_qubits, 1)
        nn.init.xavier_uniform_(self.fc_out.weight)
        nn.init.zeros_(self.fc_out.bias)

    def forward(self, x):
        x = self.kan(x)        # ⬅️ KAN thay MLP
        x = self.q_layer(x)    # ⬅️ Quantum layer
        x = self.fc_out(x)
        return torch.sigmoid(x)

# %%
# ============================================================
# 6. CLASS WEIGHTS (Balanced + Keras-style smoothing)
# ============================================================

# Chuyển y_train về numpy
y_train_np = y_train.numpy().flatten()

# Balanced class weights
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_train_np),
    y=y_train_np
)

# Keras-style smoothing
alpha_smooth = 0.7   # 0.7–0.9 đều hợp lý
class_weight_dict = {
    i: float(1 + alpha_smooth * (w - 1))
    for i, w in enumerate(class_weights)
}

print("Class Weights Dict:", class_weight_dict)
# Out:
# Class Weights Dict: {0: 1.4775193798449613, 1: 0.7980327868852459}

# %%
# ============================================================
# 7. TRAINING SETUP
# ============================================================

model = HybridKANQuantumModel(X_train.shape[1])

optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = BinaryFocalLoss(alpha=0.3, gamma= 1.0)

# Early stopping
patience = 1000
best_loss = np.inf
counter = 0
best_state = None
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
# ============================================================
# 8. TRAINING LOOP
# ============================================================

epochs = 200
for epoch in range(epochs):
    # --- TRAINING PHASE ---
    model.train()
    train_loss = 0

    for x, y in train_loader:
        optimizer.zero_grad()
        out = model(x)
        
        # 1. Tính raw loss (dạng vector, vì reduction='none' trong criterion)
        raw_loss = criterion(out, y) 
        
        # 2. Lấy trọng số cho từng mẫu trong batch từ class_weight_dict
        batch_weights = torch.tensor([class_weight_dict[int(yi.item())] for yi in y], dtype=torch.float32)
        
        # 3. Nhân trọng số và tính trung bình để ra một số thực (Scalar)
        # unsqueeze(1) giúp batch_weights có kích thước [32, 1] khớp với raw_loss
        loss = (raw_loss * batch_weights.unsqueeze(1)).mean()
        
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * x.size(0)

    train_loss /= len(train_loader.dataset)

    # --- VALIDATION PHASE (ĐÃ SỬA LỖI) ---
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for x, y in val_loader:
            out = model(x)
            
            # Tính raw loss (vector)
            raw_loss = criterion(out, y)
            
            # Lấy trọng số tương tự như training để tính loss công bằng
            batch_weights = torch.tensor([class_weight_dict[int(yi.item())] for yi in y], dtype=torch.float32)
            
            # Nhân trọng số và tính trung bình (Scalar)
            loss = (raw_loss * batch_weights.unsqueeze(1)).mean()
            
            # Cộng dồn loss (lúc này loss.item() hoạt động bình thường vì loss là scalar)
            val_loss += loss.item() * x.size(0)

    val_loss /= len(val_loader.dataset)
    print(f"Epoch {epoch+1}: train_loss={train_loss:.4f}, val_loss={val_loss:.4f}")

    # # --- EARLY STOPPING ---
    # if val_loss < best_loss:
    #     best_loss = val_loss
    #     best_state = model.state_dict()
    #     counter = 0
    # else:
    #     counter += 1
    #     if counter >= patience:
    #         print("Early stopping")
    #         break

# Load lại trọng số tốt nhất sau khi training xong
# model.load_state_dict(best_state)
# Out:
# Epoch 1: train_loss=0.1811, val_loss=0.1777
# Epoch 2: train_loss=0.1741, val_loss=0.1692
# Epoch 3: train_loss=0.1680, val_loss=0.1613
# Epoch 4: train_loss=0.1632, val_loss=0.1542
# Epoch 5: train_loss=0.1585, val_loss=0.1480
# Epoch 6: train_loss=0.1546, val_loss=0.1426
# Epoch 7: train_loss=0.1518, val_loss=0.1377
# Epoch 8: train_loss=0.1492, val_loss=0.1337
# Epoch 9: train_loss=0.1477, val_loss=0.1303
# Epoch 10: train_loss=0.1460, val_loss=0.1272
# Epoch 11: train_loss=0.1447, val_loss=0.1245
# Epoch 12: train_loss=0.1436, val_loss=0.1217
# Epoch 13: train_loss=0.1417, val_loss=0.1192
# Epoch 14: train_loss=0.1402, val_loss=0.1169
# Epoch 15: train_loss=0.1387, val_loss=0.1148
# Epoch 16: train_loss=0.1374, val_loss=0.1126
# Epoch 17: train_loss=0.1357, val_loss=0.1104
# Epoch 18: train_loss=0.1336, val_loss=0.1090
# Epoch 19: train_loss=0.1323, val_loss=0.1073
# Epoch 20: train_loss=0.1306, val_loss=0.1062
# Epoch 21: train_loss=0.1293, val_loss=0.1056
# Epoch 22: train_loss=0.1285, val_loss=0.1043
# Epoch 23: train_loss=0.1279, val_loss=0.1029
# Epoch 24: train_loss=0.1269, val_loss=0.1022
# Epoch 25: train_loss=0.1254, val_loss=0.1022
# Epoch 26: train_loss=0.1252, val_loss=0.1027
# Epoch 27: train_loss=0.1245, val_loss=0.1027
# Epoch 28: train_loss=0.1235, val_loss=0.1018
# Epoch 29: train_loss=0.1232, val_loss=0.1016
# Epoch 30: train_loss=0.1222, val_loss=0.1003
# Epoch 31: train_loss=0.1218, val_loss=0.1004
# Epoch 32: train_loss=0.1207, val_loss=0.1010
# Epoch 33: train_loss=0.1197, val_loss=0.1014
# Epoch 34: train_loss=0.1191, val_loss=0.1002
# Epoch 35: train_loss=0.1185, val_loss=0.0995
# Epoch 36: train_loss=0.1184, val_loss=0.1001
# Epoch 37: train_loss=0.1168, val_loss=0.0999
# Epoch 38: train_loss=0.1165, val_loss=0.0992
# Epoch 39: train_loss=0.1154, val_loss=0.0995
# Epoch 40: train_loss=0.1143, val_loss=0.1011
# Epoch 41: train_loss=0.1128, val_loss=0.1004
# Epoch 42: train_loss=0.1118, val_loss=0.1020
# Epoch 43: train_loss=0.1102, val_loss=0.1003
# Epoch 44: train_loss=0.1094, val_loss=0.0987
# Epoch 45: train_loss=0.1081, val_loss=0.0997
# Epoch 46: train_loss=0.1062, val_loss=0.1017
# Epoch 47: train_loss=0.1049, val_loss=0.1008
# Epoch 48: train_loss=0.1036, val_loss=0.0999
# Epoch 49: train_loss=0.1012, val_loss=0.1009
# Epoch 50: train_loss=0.0992, val_loss=0.1001
# Epoch 51: train_loss=0.0969, val_loss=0.1010
# Epoch 52: train_loss=0.0947, val_loss=0.1015
# Epoch 53: train_loss=0.0923, val_loss=0.1004
# Epoch 54: train_loss=0.0897, val_loss=0.0995
# Epoch 55: train_loss=0.0875, val_loss=0.1013
# Epoch 56: train_loss=0.0856, val_loss=0.1000
# Epoch 57: train_loss=0.0828, val_loss=0.1008
# Epoch 58: train_loss=0.0815, val_loss=0.1018
# Epoch 59: train_loss=0.0792, val_loss=0.0997
# Epoch 60: train_loss=0.0776, val_loss=0.1038
# Epoch 61: train_loss=0.0749, val_loss=0.0975
# Epoch 62: train_loss=0.0736, val_loss=0.1023
# Epoch 63: train_loss=0.0712, val_loss=0.1020
# Epoch 64: train_loss=0.0686, val_loss=0.1074
# Epoch 65: train_loss=0.0680, val_loss=0.1057
# Epoch 66: train_loss=0.0653, val_loss=0.1115
# Epoch 67: train_loss=0.0625, val_loss=0.1145
# Epoch 68: train_loss=0.0617, val_loss=0.1147
# Epoch 69: train_loss=0.0592, val_loss=0.1146
# Epoch 70: train_loss=0.0581, val_loss=0.1174
# Epoch 71: train_loss=0.0563, val_loss=0.1165
# Epoch 72: train_loss=0.0550, val_loss=0.1225
# Epoch 73: train_loss=0.0529, val_loss=0.1217
# Epoch 74: train_loss=0.0508, val_loss=0.1251
# Epoch 75: train_loss=0.0499, val_loss=0.1251
# Epoch 76: train_loss=0.0491, val_loss=0.1283
# Epoch 77: train_loss=0.0470, val_loss=0.1275
# Epoch 78: train_loss=0.0451, val_loss=0.1321
# Epoch 79: train_loss=0.0441, val_loss=0.1352
# Epoch 80: train_loss=0.0426, val_loss=0.1367
# Epoch 81: train_loss=0.0415, val_loss=0.1368
# Epoch 82: train_loss=0.0412, val_loss=0.1339
# Epoch 83: train_loss=0.0395, val_loss=0.1376
# Epoch 84: train_loss=0.0383, val_loss=0.1374
# Epoch 85: train_loss=0.0367, val_loss=0.1389
# Epoch 86: train_loss=0.0357, val_loss=0.1388
# Epoch 87: train_loss=0.0343, val_loss=0.1387
# Epoch 88: train_loss=0.0347, val_loss=0.1379
# Epoch 89: train_loss=0.0329, val_loss=0.1382
# Epoch 90: train_loss=0.0318, val_loss=0.1391
# Epoch 91: train_loss=0.0314, val_loss=0.1392
# Epoch 92: train_loss=0.0303, val_loss=0.1391
# Epoch 93: train_loss=0.0291, val_loss=0.1372
# Epoch 94: train_loss=0.0280, val_loss=0.1370
# Epoch 95: train_loss=0.0269, val_loss=0.1373
# Epoch 96: train_loss=0.0261, val_loss=0.1357
# Epoch 97: train_loss=0.0251, val_loss=0.1373
# Epoch 98: train_loss=0.0243, val_loss=0.1358
# Epoch 99: train_loss=0.0238, val_loss=0.1346
# Epoch 100: train_loss=0.0229, val_loss=0.1349
# Epoch 101: train_loss=0.0219, val_loss=0.1339
# Epoch 102: train_loss=0.0212, val_loss=0.1330
# Epoch 103: train_loss=0.0208, val_loss=0.1345
# Epoch 104: train_loss=0.0203, val_loss=0.1343
# Epoch 105: train_loss=0.0198, val_loss=0.1330
# Epoch 106: train_loss=0.0199, val_loss=0.1307
# Epoch 107: train_loss=0.0188, val_loss=0.1344
# Epoch 108: train_loss=0.0184, val_loss=0.1339
# Epoch 109: train_loss=0.0179, val_loss=0.1342
# Epoch 110: train_loss=0.0173, val_loss=0.1343
# Epoch 111: train_loss=0.0169, val_loss=0.1343
# Epoch 112: train_loss=0.0163, val_loss=0.1350
# Epoch 113: train_loss=0.0159, val_loss=0.1356
# Epoch 114: train_loss=0.0156, val_loss=0.1354
# Epoch 115: train_loss=0.0154, val_loss=0.1356
# Epoch 116: train_loss=0.0148, val_loss=0.1359
# Epoch 117: train_loss=0.0140, val_loss=0.1367
# Epoch 118: train_loss=0.0136, val_loss=0.1371
# Epoch 119: train_loss=0.0133, val_loss=0.1363
# Epoch 120: train_loss=0.0129, val_loss=0.1383
# Epoch 121: train_loss=0.0123, val_loss=0.1394
# Epoch 122: train_loss=0.0118, val_loss=0.1399
# Epoch 123: train_loss=0.0114, val_loss=0.1407
# Epoch 124: train_loss=0.0110, val_loss=0.1406
# Epoch 125: train_loss=0.0106, val_loss=0.1409
# Epoch 126: train_loss=0.0101, val_loss=0.1414
# Epoch 127: train_loss=0.0097, val_loss=0.1438
# Epoch 128: train_loss=0.0095, val_loss=0.1442
# Epoch 129: train_loss=0.0091, val_loss=0.1443
# Epoch 130: train_loss=0.0088, val_loss=0.1441
# Epoch 131: train_loss=0.0083, val_loss=0.1454
# Epoch 132: train_loss=0.0080, val_loss=0.1466
# Epoch 133: train_loss=0.0076, val_loss=0.1466
# Epoch 134: train_loss=0.0073, val_loss=0.1455
# Epoch 135: train_loss=0.0070, val_loss=0.1477
# Epoch 136: train_loss=0.0066, val_loss=0.1486
# Epoch 137: train_loss=0.0067, val_loss=0.1490
# Epoch 138: train_loss=0.0061, val_loss=0.1494
# Epoch 139: train_loss=0.0059, val_loss=0.1516
# Epoch 140: train_loss=0.0057, val_loss=0.1520
# Epoch 141: train_loss=0.0055, val_loss=0.1516
# Epoch 142: train_loss=0.0054, val_loss=0.1521
# Epoch 143: train_loss=0.0051, val_loss=0.1534
# Epoch 144: train_loss=0.0050, val_loss=0.1526
# Epoch 145: train_loss=0.0048, val_loss=0.1545
# Epoch 146: train_loss=0.0046, val_loss=0.1554
# Epoch 147: train_loss=0.0045, val_loss=0.1562
# Epoch 148: train_loss=0.0044, val_loss=0.1568
# Epoch 149: train_loss=0.0043, val_loss=0.1577
# Epoch 150: train_loss=0.0042, val_loss=0.1583
# Epoch 151: train_loss=0.0040, val_loss=0.1590
# Epoch 152: train_loss=0.0039, val_loss=0.1598
# Epoch 153: train_loss=0.0038, val_loss=0.1586
# Epoch 154: train_loss=0.0038, val_loss=0.1589
# Epoch 155: train_loss=0.0036, val_loss=0.1599
# Epoch 156: train_loss=0.0035, val_loss=0.1606
# Epoch 157: train_loss=0.0034, val_loss=0.1616
# Epoch 158: train_loss=0.0034, val_loss=0.1618
# Epoch 159: train_loss=0.0033, val_loss=0.1618
# Epoch 160: train_loss=0.0032, val_loss=0.1625
# Epoch 161: train_loss=0.0032, val_loss=0.1644
# Epoch 162: train_loss=0.0031, val_loss=0.1644
# Epoch 163: train_loss=0.0030, val_loss=0.1646
# Epoch 164: train_loss=0.0029, val_loss=0.1654
# Epoch 165: train_loss=0.0029, val_loss=0.1659
# Epoch 166: train_loss=0.0028, val_loss=0.1661
# Epoch 167: train_loss=0.0028, val_loss=0.1652
# Epoch 168: train_loss=0.0027, val_loss=0.1655
# Epoch 169: train_loss=0.0027, val_loss=0.1667
# Epoch 170: train_loss=0.0026, val_loss=0.1669
# Epoch 171: train_loss=0.0026, val_loss=0.1662
# Epoch 172: train_loss=0.0025, val_loss=0.1661
# Epoch 173: train_loss=0.0025, val_loss=0.1671
# Epoch 174: train_loss=0.0024, val_loss=0.1680
# Epoch 175: train_loss=0.0024, val_loss=0.1686
# Epoch 176: train_loss=0.0024, val_loss=0.1693
# Epoch 177: train_loss=0.0023, val_loss=0.1691
# Epoch 178: train_loss=0.0023, val_loss=0.1687
# Epoch 179: train_loss=0.0022, val_loss=0.1696
# Epoch 180: train_loss=0.0022, val_loss=0.1695
# Epoch 181: train_loss=0.0022, val_loss=0.1700
# Epoch 182: train_loss=0.0021, val_loss=0.1701
# Epoch 183: train_loss=0.0021, val_loss=0.1702
# Epoch 184: train_loss=0.0021, val_loss=0.1705
# Epoch 185: train_loss=0.0020, val_loss=0.1698
# Epoch 186: train_loss=0.0020, val_loss=0.1706
# Epoch 187: train_loss=0.0020, val_loss=0.1710
# Epoch 188: train_loss=0.0020, val_loss=0.1723
# Epoch 189: train_loss=0.0019, val_loss=0.1724
# Epoch 190: train_loss=0.0019, val_loss=0.1719
# Epoch 191: train_loss=0.0019, val_loss=0.1728
# Epoch 192: train_loss=0.0018, val_loss=0.1741
# Epoch 193: train_loss=0.0018, val_loss=0.1738
# Epoch 194: train_loss=0.0018, val_loss=0.1732
# Epoch 195: train_loss=0.0018, val_loss=0.1725
# Epoch 196: train_loss=0.0017, val_loss=0.1719
# Epoch 197: train_loss=0.0017, val_loss=0.1719
# Epoch 198: train_loss=0.0017, val_loss=0.1727
# Epoch 199: train_loss=0.0017, val_loss=0.1731
# Epoch 200: train_loss=0.0016, val_loss=0.1728

# %%
# ============================================================
# 9. EVALUATION
# ============================================================

model.eval()
y_probs, y_true = [], []

with torch.no_grad():
    for x, y in test_loader:
        out = model(x)
        y_probs.extend(out.numpy())
        y_true.extend(y.numpy())

y_probs = np.array(y_probs)
y_true = np.array(y_true)
y_pred = (y_probs >= 0.5).astype(int)

tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

print("\n=== METRICS ===")
print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
print(f"Precision: {precision_score(y_true, y_pred):.4f}")
print(f"Recall: {recall_score(y_true, y_pred):.4f}")
print(f"Specificity: {tn / (tn + fp):.4f}")
print(f"F1-score: {f1_score(y_true, y_pred):.4f}")
print(f"Balanced Accuracy: {balanced_accuracy_score(y_true, y_pred):.4f}")
print(f"ROC AUC: {roc_auc_score(y_true, y_probs):.4f}")
print(f"PR AUC: {average_precision_score(y_true, y_probs):.4f}")
print(f"MCC: {matthews_corrcoef(y_true, y_pred):.4f}")
print(f"Cohen Kappa: {cohen_kappa_score(y_true, y_pred):.4f}")
print(f"Brier Score: {brier_score_loss(y_true, y_probs):.4f}")
# Out:
# === METRICS ===
# Accuracy: 0.9041
# Precision: 0.8511
# Recall: 1.0000
# Specificity: 0.7879
# F1-score: 0.9195
# Balanced Accuracy: 0.8939
# ROC AUC: 0.9422
# PR AUC: 0.9350
# MCC: 0.8189
# Cohen Kappa: 0.8028
# Brier Score: 0.0860

# %%
# # ======================
# # KAN VISUALIZATION
# # ======================
# model.kan.plot()

# %%
# def plot_learned_function(model, X, feature_idx, n_points=200):
#     model.eval()

#     x_min = X[:, feature_idx].min()
#     x_max = X[:, feature_idx].max()
#     x_vals = torch.linspace(x_min, x_max, n_points)

#     X_base = X.mean(dim=0).repeat(n_points, 1)
#     X_base[:, feature_idx] = x_vals

#     with torch.no_grad():
#         y_vals = model(X_base).squeeze()

#     return x_vals.cpu().numpy(), y_vals.cpu().numpy()

# %%
# x, y = plot_learned_function(model, X_train, feature_idx=2)

# plt.plot(x, y)
# plt.xlabel("Feature 2 (scaled)")
# plt.ylabel("Model output")
# plt.title("Learned function for feature 2")
# plt.show()

# %% [markdown]
# ### Importance sensitivity

# %%
# def kan_feature_importance_sensitivity(model, X, eps=1e-2):
#     model.eval()
#     base_output = model(X).detach()

#     input_dim = X.shape[1]
#     importance = torch.zeros(input_dim)

#     for i in range(input_dim):
#         X_perturbed = X.clone()
#         X_perturbed[:, i] += eps

#         pert_output = model(X_perturbed).detach()
#         importance[i] = torch.mean(torch.abs(pert_output - base_output))

#     importance = importance / importance.sum()
#     return importance
# importance = kan_feature_importance_sensitivity(
#     model,
#     X_train
# )

# for name, score in zip(X_train_df.columns, importance):
#     print(f"{name}: {score:.3f}")

# %%
# # ============================
# # SIMPLIFY KAN (PRUNING)
# # ============================
# pruned_model = HybridKANQuantumModel(X_train.shape[1])
# pruned_model.load_state_dict(best_state)
# pruned_model.eval()

# with torch.no_grad():
#     _ = pruned_model(X_train)
# pruned_model.kan.prune()
# pruned_model.kan.plot()

# plt.savefig(
#     "kan_structure.png",
#     dpi=1000,                 # chuẩn thesis / paper
#     bbox_inches="tight"
# )
# plt.close()

# %%
# x, y = plot_learned_function(model, X_train, feature_idx=2)

# plt.plot(x, y)
# plt.xlabel("Feature 2 (scaled)")
# plt.ylabel("Model output")
# plt.title("Learned function for feature 2")
# plt.show()
